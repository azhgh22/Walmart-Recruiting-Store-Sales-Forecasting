# %% [markdown]
# <a href="https://colab.research.google.com/github/azhgh22/Walmart-Recruiting-Store-Sales-Forecasting/blob/main/notebooks/02_group_stat_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import userdata
token = userdata.get('GITHUB_TOKEN')
user_name = userdata.get('GITHUB_USERNAME')
mail = userdata.get('GITHUB_MAIL')

# !git config --global user.name "{user_name}"
# !git config --global user.email "{mail}"
# !git clone https://{token}@github.com/azhgh22/Walmart-Recruiting-Store-Sales-Forecasting.git

# %cd Walmart-Recruiting-Store-Sales-Forecasting
# Out:
# Cloning into 'Walmart-Recruiting-Store-Sales-Forecasting'...
# remote: Enumerating objects: 204, done.
# remote: Counting objects: 100% (204/204), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 204 (delta 95), reused 163 (delta 65), pack-reused 0 (from 0)
# Receiving objects: 100% (204/204), 6.39 MiB | 20.98 MiB/s, done.
# Resolving deltas: 100% (95/95), done.
# /content/Walmart-Recruiting-Store-Sales-Forecasting

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 1)) (1.7.4.5)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (0.20.1)
# Collecting onnx (from -r requirements.txt (line 3))
#   Downloading onnx-1.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 5)) (2.0.2)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (2.1.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (1.6.1)
# Collecting dagshub (from -r requirements.txt (line 8))
#   Downloading dagshub-0.5.10-py3-none-any.whl.metadata (12 kB)
# Collecting mlflow (from -r requirements.txt (line 9))
#   Downloading mlflow-3.1.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle->-r requirements.txt (line 1)) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.11/dist-packages (from kaggle->-r requirements.txt (line 1)) (2025.6.15)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.11/dist-packages (from kaggle->-r requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from kaggle->-r requirements.txt (line 1)) (3.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from kaggle->-r requirements.txt (line 1)) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kaggle->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle->-r requirements.txt (line 1)) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle->-r requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from kaggle->-r requirements.txt (line 1)) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle->-r requirements.txt (line 1)) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle->-r requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from kaggle->-r requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kaggle->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 2)) (8.2.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 2)) (3.1.44)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 2)) (24.2)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 2)) (4.3.8)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 2)) (5.9.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 2)) (2.11.7)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 2)) (2.32.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 2)) (1.3.6)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /usr/local/lib/python3.11/dist-packages (from wandb->-r requirements.txt (line 2)) (4.14.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->-r requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->-r requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost->-r requirements.txt (line 6)) (2.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from xgboost->-r requirements.txt (line 6)) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r requirements.txt (line 7)) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->-r requirements.txt (line 7)) (3.6.0)
# Collecting appdirs>=1.4.4 (from dagshub->-r requirements.txt (line 8))
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from dagshub->-r requirements.txt (line 8)) (0.28.1)
# Requirement already satisfied: rich>=13.1.0 in /usr/local/lib/python3.11/dist-packages (from dagshub->-r requirements.txt (line 8)) (13.9.4)
# Collecting dacite~=1.6.0 (from dagshub->-r requirements.txt (line 8))
#   Downloading dacite-1.6.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: tenacity>=8.2.2 in /usr/local/lib/python3.11/dist-packages (from dagshub->-r requirements.txt (line 8)) (8.5.0)
# Collecting gql[requests] (from dagshub->-r requirements.txt (line 8))
#   Downloading gql-3.5.3-py2.py3-none-any.whl.metadata (9.4 kB)
# Collecting dataclasses-json (from dagshub->-r requirements.txt (line 8))
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting treelib>=1.6.4 (from dagshub->-r requirements.txt (line 8))
#   Downloading treelib-1.8.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pathvalidate>=3.0.0 (from dagshub->-r requirements.txt (line 8))
#   Downloading pathvalidate-3.3.1-py3-none-any.whl.metadata (12 kB)
# Collecting boto3 (from dagshub->-r requirements.txt (line 8))
#   Downloading boto3-1.39.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting semver (from dagshub->-r requirements.txt (line 8))
#   Downloading semver-3.0.4-py3-none-any.whl.metadata (6.8 kB)
# Collecting dagshub-annotation-converter>=0.1.5 (from dagshub->-r requirements.txt (line 8))
#   Downloading dagshub_annotation_converter-0.1.10-py3-none-any.whl.metadata (2.5 kB)
# Collecting mlflow-skinny==3.1.1 (from mlflow->-r requirements.txt (line 9))
#   Downloading mlflow_skinny-3.1.1-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.11/dist-packages (from mlflow->-r requirements.txt (line 9)) (3.1.1)
# Collecting alembic!=1.10.0,<2 (from mlflow->-r requirements.txt (line 9))
#   Downloading alembic-1.16.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting docker<8,>=4.0.0 (from mlflow->-r requirements.txt (line 9))
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow->-r requirements.txt (line 9))
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow->-r requirements.txt (line 9))
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.11/dist-packages (from mlflow->-r requirements.txt (line 9)) (3.10.0)
# Requirement already satisfied: pyarrow<21,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow->-r requirements.txt (line 9)) (18.1.0)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow->-r requirements.txt (line 9)) (2.0.41)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.1->mlflow->-r requirements.txt (line 9)) (5.5.2)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.1->mlflow->-r requirements.txt (line 9)) (3.1.1)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.1.1->mlflow->-r requirements.txt (line 9))
#   Downloading databricks_sdk-0.57.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: fastapi<1 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.1->mlflow->-r requirements.txt (line 9)) (0.115.14)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.1->mlflow->-r requirements.txt (line 9)) (8.7.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.1.1->mlflow->-r requirements.txt (line 9))
#   Downloading opentelemetry_api-1.34.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.1.1->mlflow->-r requirements.txt (line 9))
#   Downloading opentelemetry_sdk-1.34.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.1->mlflow->-r requirements.txt (line 9)) (0.5.3)
# Requirement already satisfied: uvicorn<1 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==3.1.1->mlflow->-r requirements.txt (line 9)) (0.35.0)
# Requirement already satisfied: Mako in /usr/lib/python3/dist-packages (from alembic!=1.10.0,<2->mlflow->-r requirements.txt (line 9)) (1.1.3)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from dagshub-annotation-converter>=0.1.5->dagshub->-r requirements.txt (line 8)) (5.4.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from dagshub-annotation-converter>=0.1.5->dagshub->-r requirements.txt (line 8)) (11.2.1)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow->-r requirements.txt (line 9)) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow->-r requirements.txt (line 9)) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow->-r requirements.txt (line 9)) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow->-r requirements.txt (line 9)) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow->-r requirements.txt (line 9)) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 2)) (4.0.12)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow->-r requirements.txt (line 9))
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow->-r requirements.txt (line 9))
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->dagshub->-r requirements.txt (line 8)) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.23.0->dagshub->-r requirements.txt (line 8)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.23.0->dagshub->-r requirements.txt (line 8)) (0.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow->-r requirements.txt (line 9)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow->-r requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow->-r requirements.txt (line 9)) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow->-r requirements.txt (line 9)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow->-r requirements.txt (line 9)) (3.2.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb->-r requirements.txt (line 2)) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.1.0->dagshub->-r requirements.txt (line 8)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.1.0->dagshub->-r requirements.txt (line 8)) (2.19.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow->-r requirements.txt (line 9)) (3.2.3)
# Collecting botocore<1.40.0,>=1.39.2 (from boto3->dagshub->-r requirements.txt (line 8))
#   Downloading botocore-1.39.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->dagshub->-r requirements.txt (line 8))
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.14.0,>=0.13.0 (from boto3->dagshub->-r requirements.txt (line 8))
#   Downloading s3transfer-0.13.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->dagshub->-r requirements.txt (line 8))
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->dagshub->-r requirements.txt (line 8))
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: yarl<2.0,>=1.6 in /usr/local/lib/python3.11/dist-packages (from gql[requests]->dagshub->-r requirements.txt (line 8)) (1.20.1)
# Collecting backoff<3.0,>=1.11.1 (from gql[requests]->dagshub->-r requirements.txt (line 8))
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests-toolbelt<2,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from gql[requests]->dagshub->-r requirements.txt (line 8)) (1.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.23.0->dagshub->-r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.11/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.1->mlflow->-r requirements.txt (line 9)) (2.38.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi<1->mlflow-skinny==3.1.1->mlflow->-r requirements.txt (line 9)) (0.46.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->-r requirements.txt (line 2)) (5.0.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.1.1->mlflow->-r requirements.txt (line 9)) (3.23.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.1.0->dagshub->-r requirements.txt (line 8)) (0.1.2)
# Collecting opentelemetry-semantic-conventions==0.55b1 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.1.1->mlflow->-r requirements.txt (line 9))
#   Downloading opentelemetry_semantic_conventions-0.55b1-py3-none-any.whl.metadata (2.5 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->dagshub->-r requirements.txt (line 8))
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: multidict>=4.0 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.6->gql[requests]->dagshub->-r requirements.txt (line 8)) (6.6.3)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from yarl<2.0,>=1.6->gql[requests]->dagshub->-r requirements.txt (line 8)) (0.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.1->mlflow->-r requirements.txt (line 9)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.1->mlflow->-r requirements.txt (line 9)) (4.9.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.1.1->mlflow->-r requirements.txt (line 9)) (0.6.1)
# Downloading onnx-1.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 58.5 MB/s eta 0:00:00
# Downloading dagshub-0.5.10-py3-none-any.whl (260 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 14.4 MB/s eta 0:00:00
# Downloading mlflow-3.1.1-py3-none-any.whl (24.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.7/24.7 MB 42.5 MB/s eta 0:00:00
# Downloading mlflow_skinny-3.1.1-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 43.5 MB/s eta 0:00:00
# Downloading alembic-1.16.2-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.7/242.7 kB 13.9 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading dacite-1.6.0-py3-none-any.whl (12 kB)
# Downloading dagshub_annotation_converter-0.1.10-py3-none-any.whl (33 kB)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 10.8 MB/s eta 0:00:00
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 7.9 MB/s eta 0:00:00
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 5.8 MB/s eta 0:00:00
# Downloading pathvalidate-3.3.1-py3-none-any.whl (24 kB)
# Downloading treelib-1.8.0-py3-none-any.whl (30 kB)
# Downloading boto3-1.39.2-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 9.0 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading semver-3.0.4-py3-none-any.whl (17 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading botocore-1.39.2-py3-none-any.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 73.4 MB/s eta 0:00:00
# Downloading databricks_sdk-0.57.0-py3-none-any.whl (733 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 733.8/733.8 kB 36.9 MB/s eta 0:00:00
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 14.4 MB/s eta 0:00:00
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.6 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.34.1-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 4.0 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.34.1-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 8.7 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.55b1-py3-none-any.whl (196 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 12.4 MB/s eta 0:00:00
# Downloading s3transfer-0.13.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.2/85.2 kB 6.3 MB/s eta 0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading gql-3.5.3-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 6.4 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: appdirs, treelib, semver, pathvalidate, onnx, mypy-extensions, marshmallow, jmespath, gunicorn, graphql-core, dacite, backoff, typing-inspect, opentelemetry-api, graphql-relay, gql, docker, botocore, alembic, s3transfer, opentelemetry-semantic-conventions, graphene, dataclasses-json, databricks-sdk, dagshub-annotation-converter, opentelemetry-sdk, boto3, mlflow-skinny, dagshub, mlflow
# Successfully installed alembic-1.16.2 appdirs-1.4.4 backoff-2.2.1 boto3-1.39.2 botocore-1.39.2 dacite-1.6.0 dagshub-0.5.10 dagshub-annotation-converter-0.1.10 databricks-sdk-0.57.0 dataclasses-json-0.6.7 docker-7.1.0 gql-3.5.3 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 gunicorn-23.0.0 jmespath-1.0.1 marshmallow-3.26.1 mlflow-3.1.1 mlflow-skinny-3.1.1 mypy-extensions-1.1.0 onnx-1.18.0 opentelemetry-api-1.34.1 opentelemetry-sdk-1.34.1 opentelemetry-semantic-conventions-0.55b1 pathvalidate-3.3.1 s3transfer-0.13.0 semver-3.0.4 treelib-1.8.0 typing-inspect-0.9.0

# %%
from google.colab import userdata
kaggle_json_path = userdata.get('KAGGLE_JSON_PATH')
! ./src/data_loader.sh -f {kaggle_json_path}
# Out:
# Setting up Kaggle credentials...
# Ensuring data directory exists at 'data/'...
# Downloading data from Kaggle for competition: 'walmart-recruiting-store-sales-forecasting'...
# Downloading walmart-recruiting-store-sales-forecasting.zip to data
#   0% 0.00/2.70M [00:00<?, ?B/s]
# 100% 2.70M/2.70M [00:00<00:00, 448MB/s]
# Unzipping files...
# Archive:  walmart-recruiting-store-sales-forecasting.zip
#   inflating: features.csv.zip
#   inflating: sampleSubmission.csv.zip
#   inflating: stores.csv
#   inflating: test.csv.zip
#   inflating: train.csv.zip
# Archive:  features.csv.zip
#   inflating: features.csv
# Archive:  sampleSubmission.csv.zip
#   inflating: sampleSubmission.csv
# Archive:  test.csv.zip
#   inflating: test.csv
# Archive:  train.csv.zip
#   inflating: train.csv
# Data downloaded and extracted successfully to 'data/'.

# %% [markdown]
# # Load Data

# %%
from src import data_loader, processing
import importlib
importlib.reload(processing)

dataframes = data_loader.load_raw_data()
df = processing.run_preprocessing(dataframes, process_test=False)['train']
X_train, y_train, X_valid, y_valid = processing.split_data(df, separate_target=True)

print(f"Shapes of X_train and y_train: {X_train.shape}, {y_train.shape}")
print(f"Shapes of X_valid and y_valid: {X_valid.shape}, {y_valid.shape}")
# Out:
# Data loading complete.
# Shapes of X_train and y_train: (279085, 15), (279085,)
# Shapes of X_valid and y_valid: (142485, 15), (142485,)

# %%
X_train
# Out:
#         Store  Dept       Date  IsHoliday  Temperature  Fuel_Price  MarkDown1  \
# 0           1     1 2010-02-05      False        42.31       2.572        NaN
# 1           1     2 2010-02-05      False        42.31       2.572        NaN
# 2           1     3 2010-02-05      False        42.31       2.572        NaN
# 3           1     4 2010-02-05      False        42.31       2.572        NaN
# 4           1     5 2010-02-05      False        42.31       2.572        NaN
# ...       ...   ...        ...        ...          ...         ...        ...
# 279080     45    93 2011-11-25       True        48.71       3.492     140.87
# 279081     45    94 2011-11-25       True        48.71       3.492     140.87
# 279082     45    95 2011-11-25       True        48.71       3.492     140.87
# 279083     45    97 2011-11-25       True        48.71       3.492     140.87
# 279084     45    98 2011-11-25       True        48.71       3.492     140.87
#
#         MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# 0             NaN        NaN        NaN        NaN  211.096358         8.106
# 1             NaN        NaN        NaN        NaN  211.096358         8.106
# 2             NaN        NaN        NaN        NaN  211.096358         8.106
# 3             NaN        NaN        NaN        NaN  211.096358         8.106
# 4             NaN        NaN        NaN        NaN  211.096358         8.106
# ...           ...        ...        ...        ...         ...           ...
# 279080     384.82   26961.99      28.59    1110.12  188.350400         8.523
# 279081     384.82   26961.99      28.59    1110.12  188.350400         8.523
# 279082     384.82   26961.99      28.59    1110.12  188.350400         8.523
# 279083     384.82   26961.99      28.59    1110.12  188.350400         8.523
# 279084     384.82   26961.99      28.59    1110.12  188.350400         8.523
#
#        Type    Size
# 0         A  151315
# 1         A  151315
# 2         A  151315
# 3         A  151315
# 4         A  151315
# ...     ...     ...
# 279080    B  118221
# 279081    B  118221
# 279082    B  118221
# 279083    B  118221
# 279084    B  118221
#
# [279085 rows x 15 columns]

# %%
X_valid
# Out:
#         Store  Dept       Date  IsHoliday  Temperature  Fuel_Price  MarkDown1  \
# 279085      1     1 2011-12-02      False        48.91       3.172    5629.51
# 279086      1     2 2011-12-02      False        48.91       3.172    5629.51
# 279087      1     3 2011-12-02      False        48.91       3.172    5629.51
# 279088      1     4 2011-12-02      False        48.91       3.172    5629.51
# 279089      1     5 2011-12-02      False        48.91       3.172    5629.51
# ...       ...   ...        ...        ...          ...         ...        ...
# 421565     45    93 2012-10-26      False        58.85       3.882    4018.91
# 421566     45    94 2012-10-26      False        58.85       3.882    4018.91
# 421567     45    95 2012-10-26      False        58.85       3.882    4018.91
# 421568     45    97 2012-10-26      False        58.85       3.882    4018.91
# 421569     45    98 2012-10-26      False        58.85       3.882    4018.91
#
#         MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# 279085      68.00    1398.11    2084.64   20475.32  218.714733         7.866
# 279086      68.00    1398.11    2084.64   20475.32  218.714733         7.866
# 279087      68.00    1398.11    2084.64   20475.32  218.714733         7.866
# 279088      68.00    1398.11    2084.64   20475.32  218.714733         7.866
# 279089      68.00    1398.11    2084.64   20475.32  218.714733         7.866
# ...           ...        ...        ...        ...         ...           ...
# 421565      58.08     100.00     211.94     858.33  192.308899         8.667
# 421566      58.08     100.00     211.94     858.33  192.308899         8.667
# 421567      58.08     100.00     211.94     858.33  192.308899         8.667
# 421568      58.08     100.00     211.94     858.33  192.308899         8.667
# 421569      58.08     100.00     211.94     858.33  192.308899         8.667
#
#        Type    Size
# 279085    A  151315
# 279086    A  151315
# 279087    A  151315
# 279088    A  151315
# 279089    A  151315
# ...     ...     ...
# 421565    B  118221
# 421566    B  118221
# 421567    B  118221
# 421568    B  118221
# 421569    B  118221
#
# [142485 rows x 15 columns]

# %% [markdown]
# # Store AVG using XGboost

# %%
from feature_engineering import grouper as grp
import importlib
importlib.reload(grp)

X_train_store, y_train_store = grp.group_and_aggregate(X_train, y_train, groupby_cols=['Store', 'Date', 'IsHoliday'], y_aggfunc='mean')
X_valid_store, y_valid_store = grp.group_and_aggregate(X_valid, y_valid, groupby_cols=['Store', 'Date', 'IsHoliday'], y_aggfunc='mean')

X_train_store
# Out:
#       Store       Date  IsHoliday  Temperature  Fuel_Price  MarkDown1  \
# 0         1 2010-02-05      False        42.31       2.572        NaN
# 1         1 2010-02-12       True        38.51       2.548        NaN
# 2         1 2010-02-19      False        39.93       2.514        NaN
# 3         1 2010-02-26      False        46.63       2.561        NaN
# 4         1 2010-03-05      False        46.50       2.625        NaN
# ...     ...        ...        ...          ...         ...        ...
# 4270     45 2011-10-28      False        51.78       3.569        NaN
# 4271     45 2011-11-04      False        43.92       3.551        NaN
# 4272     45 2011-11-11      False        47.65       3.530   23052.25
# 4273     45 2011-11-18      False        51.34       3.530    4240.34
# 4274     45 2011-11-25       True        48.71       3.492     140.87
#
#       MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  \
# 0           NaN        NaN        NaN        NaN  211.096358         8.106
# 1           NaN        NaN        NaN        NaN  211.242170         8.106
# 2           NaN        NaN        NaN        NaN  211.289143         8.106
# 3           NaN        NaN        NaN        NaN  211.319643         8.106
# 4           NaN        NaN        NaN        NaN  211.350143         8.106
# ...         ...        ...        ...        ...         ...           ...
# 4270        NaN        NaN        NaN        NaN  187.877491         8.523
# 4271        NaN        NaN        NaN        NaN  187.970363         8.523
# 4272    5449.62     189.24    3355.69    3864.60  188.063234         8.523
# 4273     132.96     111.71     270.14    7073.00  188.198365         8.523
# 4274     384.82   26961.99      28.59    1110.12  188.350400         8.523
#
#      Type    Size
# 0       A  151315
# 1       A  151315
# 2       A  151315
# 3       A  151315
# 4       A  151315
# ...   ...     ...
# 4270    B  118221
# 4271    B  118221
# 4272    B  118221
# 4273    B  118221
# 4274    B  118221
#
# [4275 rows x 14 columns]

# %% [markdown]
# Apply feature engineering techniques for XGBoost modeling.

# %%
from feature_engineering import time_features, feature_transformers

import importlib
importlib.reload(time_features)
importlib.reload(feature_transformers)

params = {
    'add_week_num' : True,
    'add_holiday_flags' : True,
    'add_holiday_proximity': True,
    'add_holiday_windows': True,
    'add_fourier_features': True,
    'add_month_and_year': True,
    'replace_time_index': True,
}

feature_adder = time_features.FeatureAdder(**params)
X_train_store = feature_adder.fit_transform(X_train_store)
X_valid_store = feature_adder.transform(X_valid_store)

object_transformer = feature_transformers.ObjectToCategory()
X_train_store = object_transformer.fit_transform(X_train_store)
X_valid_store = object_transformer.transform(X_valid_store)

adder = feature_transformers.GroupStatFeatureAdder(groupby_cols='Store', aggfunc='mean')
X_train_store = adder.fit_transform(X_train_store, y_train_store)
X_valid_store = adder.transform(X_valid_store)

make_categorical_transformer = feature_transformers.MakeCategorical(['Store'])
X_train_store = make_categorical_transformer.fit_transform(X_train_store)
X_valid_store = make_categorical_transformer.transform(X_valid_store)

columns_to_drop=['MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5']
change_columns_transformer = feature_transformers.ChangeColumns(columns_to_drop=columns_to_drop)
X_train_store = change_columns_transformer.fit_transform(X_train_store)
X_valid_store = change_columns_transformer.transform(X_valid_store)

X_valid_store
# Out:
#      Store  IsHoliday  Temperature  Fuel_Price         CPI  Unemployment Type  \
# 0        1      False        48.91       3.172  218.714733         7.866    A
# 1        1      False        43.93       3.158  218.961846         7.866    A
# 2        1      False        51.63       3.159  219.179453         7.866    A
# 3        1      False        47.96       3.112  219.357722         7.866    A
# 4        1       True        44.55       3.129  219.535990         7.866    A
# ...    ...        ...          ...         ...         ...           ...  ...
# 2155    45      False        64.88       3.997  192.013558         8.684    B
# 2156    45      False        64.89       3.985  192.170412         8.667    B
# 2157    45      False        54.47       4.000  192.327265         8.667    B
# 2158    45      False        56.47       3.969  192.330854         8.667    B
# 2159    45      False        58.85       3.882  192.308899         8.667    B
#
#         Size  Month  Year  ...  Days_until_next_SuperBowl  \
# 0     151315     12  2011  ...                         70
# 1     151315     12  2011  ...                         63
# 2     151315     12  2011  ...                         56
# 3     151315     12  2011  ...                         49
# 4     151315     12  2011  ...                         42
# ...      ...    ...   ...  ...                        ...
# 2155  118221      9  2012  ...                        133
# 2156  118221     10  2012  ...                        126
# 2157  118221     10  2012  ...                        119
# 2158  118221     10  2012  ...                        112
# 2159  118221     10  2012  ...                        105
#
#       Days_since_last_SuperBowl  Days_until_next_Thanksgiving  \
# 0                           294                           357
# 1                           301                           350
# 2                           308                           343
# 3                           315                           336
# 4                           322                           329
# ...                         ...                           ...
# 2155                        231                            56
# 2156                        238                            49
# 2157                        245                            42
# 2158                        252                            35
# 2159                        259                            28
#
#       Days_since_last_Thanksgiving  Days_until_next_Christmas  \
# 0                                7                         28
# 1                               14                         21
# 2                               21                         14
# 3                               28                          7
# 4                               35                          0
# ...                            ...                        ...
# 2155                           308                         91
# 2156                           315                         84
# 2157                           322                         77
# 2158                           329                         70
# 2159                           336                         63
#
#       Days_since_last_Christmas  Days_until_next_LaborDay  \
# 0                           336                       280
# 1                           343                       273
# 2                           350                       266
# 3                           357                       259
# 4                           364                       252
# ...                         ...                       ...
# 2155                        273                       343
# 2156                        280                       336
# 2157                        287                       329
# 2158                        294                       322
# 2159                        301                       315
#
#       Days_since_last_LaborDay  Date    Store_mean
# 0                           84    95  21335.179178
# 1                           91    96  21335.179178
# 2                           98    97  21335.179178
# 3                          105    98  21335.179178
# 4                          112    99  21335.179178
# ...                        ...   ...           ...
# 2155                        21   138  11639.767411
# 2156                        28   139  11639.767411
# 2157                        35   140  11639.767411
# 2158                        42   141  11639.767411
# 2159                        49   142  11639.767411
#
# [2160 rows x 39 columns]

# %%
from xgboost import XGBRegressor
from src.utils import wmae
from src.cross_validation import manual_model_search

model = XGBRegressor(
    objective='reg:squarederror',
    enable_categorical=True,
    random_state=42
)

param_grid = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7, 10],
}


metric_kwargs = {
    'is_holiday': X_valid_store['IsHoliday']
}

best_model, best_params, best_score = manual_model_search(
    model=model,
    param_grid=param_grid,
    X_train=X_train_store,
    y_train=y_train_store,
    X_valid=X_valid_store,
    y_valid=y_valid_store,
    metric_func=wmae,
    metric_kwargs=metric_kwargs
)

print("\nBest Params:", best_params)
print("Best Validation Score:", best_score)
# Out:
# Params: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3} -> Score: 2577.2952
# Params: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5} -> Score: 2548.0074
# Params: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 7} -> Score: 2528.4732
# Params: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 10} -> Score: 2508.5963
# Params: {'n_estimators': 100, 'learning_rate': 0.05, 'max_depth': 3} -> Score: 1085.9913
# Params: {'n_estimators': 100, 'learning_rate': 0.05, 'max_depth': 5} -> Score: 942.5534
# Params: {'n_estimators': 100, 'learning_rate': 0.05, 'max_depth': 7} -> Score: 898.6599
# Params: {'n_estimators': 100, 'learning_rate': 0.05, 'max_depth': 10} -> Score: 905.4130
# Params: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3} -> Score: 918.9623
# Params: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5} -> Score: 842.9912
# Params: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 7} -> Score: 846.4202
# Params: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 10} -> Score: 889.7755
# Params: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 3} -> Score: 1592.3475
# Params: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 5} -> Score: 1403.3816
# Params: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 7} -> Score: 1361.9816
# Params: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 10} -> Score: 1333.9675
# Params: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 3} -> Score: 947.7465
# Params: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 5} -> Score: 850.5160
# Params: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 7} -> Score: 851.4373
# Params: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 10} -> Score: 881.3760
# Params: {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3} -> Score: 850.0605
# Params: {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 5} -> Score: 826.0565
# Params: {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 7} -> Score: 824.7038
# Params: {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 10} -> Score: 887.6490
# Params: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 3} -> Score: 1282.2307
# Params: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 5} -> Score: 1087.3750
# Params: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 7} -> Score: 1028.2217
# Params: {'n_estimators': 300, 'learning_rate': 0.01, 'max_depth': 10} -> Score: 1018.9517
# Params: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 3} -> Score: 906.5471
# Params: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 5} -> Score: 837.2503
# Params: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 7} -> Score: 839.5606
# Params: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 10} -> Score: 879.0819
# Params: {'n_estimators': 300, 'learning_rate': 0.1, 'max_depth': 3} -> Score: 829.5826
# Params: {'n_estimators': 300, 'learning_rate': 0.1, 'max_depth': 5} -> Score: 827.4329
# Params: {'n_estimators': 300, 'learning_rate': 0.1, 'max_depth': 7} -> Score: 828.3716
# Params: {'n_estimators': 300, 'learning_rate': 0.1, 'max_depth': 10} -> Score: 887.4305
#
# Best Params: {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 7}
# Best Validation Score: 824.7038007789026

# %%
from xgboost import XGBRegressor
from src.utils import wmae
from src.cross_validation import manual_model_search

model = XGBRegressor(
    objective='reg:squarederror',
    enable_categorical=True,
    random_state=42,
    n_estimators=200,
    learning_rate=0.1,
    max_depth=7,
)

param_grid = {
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.5, 0.7, 1.0],
    'min_child_weight': [1, 5, 10]
}

metric_kwargs = {
    'is_holiday': X_valid_store['IsHoliday']
}

best_model, best_params, best_score = manual_model_search(
    model=model,
    param_grid=param_grid,
    X_train=X_train_store,
    y_train=y_train_store,
    X_valid=X_valid_store,
    y_valid=y_valid_store,
    metric_func=wmae,
    metric_kwargs=metric_kwargs
)

print("\nBest Params:", best_params)
print("Best Validation Score:", best_score)
# Out:
# Params: {'subsample': 0.6, 'colsample_bytree': 0.5, 'min_child_weight': 1} -> Score: 864.6331
# Params: {'subsample': 0.6, 'colsample_bytree': 0.5, 'min_child_weight': 5} -> Score: 830.0689
# Params: {'subsample': 0.6, 'colsample_bytree': 0.5, 'min_child_weight': 10} -> Score: 824.5584
# Params: {'subsample': 0.6, 'colsample_bytree': 0.7, 'min_child_weight': 1} -> Score: 840.2918
# Params: {'subsample': 0.6, 'colsample_bytree': 0.7, 'min_child_weight': 5} -> Score: 835.5368
# Params: {'subsample': 0.6, 'colsample_bytree': 0.7, 'min_child_weight': 10} -> Score: 847.5559
# Params: {'subsample': 0.6, 'colsample_bytree': 1.0, 'min_child_weight': 1} -> Score: 848.4305
# Params: {'subsample': 0.6, 'colsample_bytree': 1.0, 'min_child_weight': 5} -> Score: 800.0636
# Params: {'subsample': 0.6, 'colsample_bytree': 1.0, 'min_child_weight': 10} -> Score: 820.8207
# Params: {'subsample': 0.8, 'colsample_bytree': 0.5, 'min_child_weight': 1} -> Score: 863.9522
# Params: {'subsample': 0.8, 'colsample_bytree': 0.5, 'min_child_weight': 5} -> Score: 836.3337
# Params: {'subsample': 0.8, 'colsample_bytree': 0.5, 'min_child_weight': 10} -> Score: 824.6220
# Params: {'subsample': 0.8, 'colsample_bytree': 0.7, 'min_child_weight': 1} -> Score: 844.6571
# Params: {'subsample': 0.8, 'colsample_bytree': 0.7, 'min_child_weight': 5} -> Score: 825.7764
# Params: {'subsample': 0.8, 'colsample_bytree': 0.7, 'min_child_weight': 10} -> Score: 1086.0891
# Params: {'subsample': 0.8, 'colsample_bytree': 1.0, 'min_child_weight': 1} -> Score: 851.9549
# Params: {'subsample': 0.8, 'colsample_bytree': 1.0, 'min_child_weight': 5} -> Score: 823.5733
# Params: {'subsample': 0.8, 'colsample_bytree': 1.0, 'min_child_weight': 10} -> Score: 1441.4894
# Params: {'subsample': 1.0, 'colsample_bytree': 0.5, 'min_child_weight': 1} -> Score: 828.5591
# Params: {'subsample': 1.0, 'colsample_bytree': 0.5, 'min_child_weight': 5} -> Score: 859.5113
# Params: {'subsample': 1.0, 'colsample_bytree': 0.5, 'min_child_weight': 10} -> Score: 903.7695
# Params: {'subsample': 1.0, 'colsample_bytree': 0.7, 'min_child_weight': 1} -> Score: 857.0026
# Params: {'subsample': 1.0, 'colsample_bytree': 0.7, 'min_child_weight': 5} -> Score: 828.3924
# Params: {'subsample': 1.0, 'colsample_bytree': 0.7, 'min_child_weight': 10} -> Score: 931.0735
# Params: {'subsample': 1.0, 'colsample_bytree': 1.0, 'min_child_weight': 1} -> Score: 824.7038
# Params: {'subsample': 1.0, 'colsample_bytree': 1.0, 'min_child_weight': 5} -> Score: 847.4361
# Params: {'subsample': 1.0, 'colsample_bytree': 1.0, 'min_child_weight': 10} -> Score: 1132.7145
#
# Best Params: {'subsample': 0.6, 'colsample_bytree': 1.0, 'min_child_weight': 5}
# Best Validation Score: 800.0635538598495

# %%
from re import sub
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from src.utils import wmae as compute_wmae

store_model = XGBRegressor(
    objective='reg:squarederror',
    enable_categorical=True,
    random_state=42,
    n_estimators=200,
    learning_rate=0.1,
    max_depth=7,
    subsample=0.6,
    colsample_bytree=1.0,
    min_child_weight=5
)

store_model.fit(X_train_store, y_train_store)
store_train_preds = store_model.predict(X_train_store)
store_valid_preds = store_model.predict(X_valid_store)

wma = compute_wmae(y_valid_store, store_valid_preds, is_holiday=X_valid_store['IsHoliday'])
print(f"Validation WMAE: {wma:.2f}")
mae = mean_absolute_error(y_valid_store, store_valid_preds)
print(f"Validation MAE: {mae:.2f}")

wma = compute_wmae(y_train_store, store_train_preds, is_holiday=X_train_store['IsHoliday'])
print(f"Train WMAE: {wma:.2f}")
mae = mean_absolute_error(y_train_store, store_train_preds)
print(f"Train MAE: {mae:.2f}")
# Out:
# Validation WMAE: 800.06
# Validation MAE: 786.72
# Train WMAE: 253.43
# Train MAE: 254.05

# %%
valid_store_results = X_valid_store[['Store', 'Date']].copy()
valid_store_results['Store_Prediction'] = store_valid_preds

train_store_results = X_train_store[['Store', 'Date']].copy()
train_store_results['Store_Prediction'] = store_train_preds

valid_store_results
# Out:
#      Store  Date  Store_Prediction
# 0        1    95      23446.662109
# 1        1    96      24663.173828
# 2        1    97      26697.953125
# 3        1    98      34912.000000
# 4        1    99      19632.361328
# ...    ...   ...               ...
# 2155    45   138      10711.922852
# 2156    45   139      11598.338867
# 2157    45   140      11298.853516
# 2158    45   141      11547.879883
# 2159    45   142      11497.519531
#
# [2160 rows x 3 columns]

# %% [markdown]
# # Department AVG using XGboost

# %%
from feature_engineering import grouper as grp
import importlib
importlib.reload(grp)

X_train_dept, y_train_dept = grp.group_and_aggregate(X_train, y_train, groupby_cols=['Date', 'IsHoliday', 'Dept'], y_aggfunc='mean')
X_valid_dept, y_valid_dept = grp.group_and_aggregate(X_valid, y_valid, groupby_cols=['Date', 'IsHoliday', 'Dept'], y_aggfunc='mean')

adder = feature_transformers.GroupStatFeatureAdder(groupby_cols='Dept', aggfunc='mean')
X_train_dept = adder.fit_transform(X_train_dept, y_train_dept)
X_valid_dept = adder.transform(X_valid_dept)

X_train_dept
# Out:
#            Date  IsHoliday  Dept     Dept_mean
# 0    2010-02-05      False     1  18960.208250
# 1    2010-02-05      False     2  43193.216126
# 2    2010-02-05      False     3  11592.413923
# 3    2010-02-05      False     4  25743.993319
# 4    2010-02-05      False     5  22271.562580
# ...         ...        ...   ...           ...
# 7335 2011-11-25       True    95  69428.162894
# 7336 2011-11-25       True    96  15280.287656
# 7337 2011-11-25       True    97  14176.271374
# 7338 2011-11-25       True    98   7004.618635
# 7339 2011-11-25       True    99    123.992901
#
# [7340 rows x 4 columns]

# %%
from feature_engineering import time_features, feature_transformers

import importlib
importlib.reload(time_features)
importlib.reload(feature_transformers)

params = {
    'add_week_num' : True,
    'add_holiday_flags' : True,
    'add_holiday_proximity': True,
    'add_holiday_windows': True,
    'add_fourier_features': True,
    'add_month_and_year': True,
    'replace_time_index': True,
}

feature_adder = time_features.FeatureAdder(**params)
X_train_dept = feature_adder.fit_transform(X_train_dept)
X_valid_dept = feature_adder.transform(X_valid_dept)

object_transformer = feature_transformers.ObjectToCategory()
X_train_dept = object_transformer.fit_transform(X_train_dept)
X_valid_dept = object_transformer.transform(X_valid_dept)

make_categorical_transformer = feature_transformers.MakeCategorical(['Dept'])
X_train_dept = make_categorical_transformer.fit_transform(X_train_dept)
X_valid_dept = make_categorical_transformer.transform(X_valid_dept)


X_train_dept
# Out:
#       IsHoliday Dept     Dept_mean  Month  Year  WeekOfYear  Is_SuperBowl  \
# 0         False    1  18960.208250      2  2010           5             0
# 1         False    2  43193.216126      2  2010           5             0
# 2         False    3  11592.413923      2  2010           5             0
# 3         False    4  25743.993319      2  2010           5             0
# 4         False    5  22271.562580      2  2010           5             0
# ...         ...  ...           ...    ...   ...         ...           ...
# 7335       True   95  69428.162894     11  2011          47             0
# 7336       True   96  15280.287656     11  2011          47             0
# 7337       True   97  14176.271374     11  2011          47             0
# 7338       True   98   7004.618635     11  2011          47             0
# 7339       True   99    123.992901     11  2011          47             0
#
#       Is_Thanksgiving  Is_Christmas  Is_LaborDay  ...  month_cos  \
# 0                   0             0            0  ...   0.500000
# 1                   0             0            0  ...   0.500000
# 2                   0             0            0  ...   0.500000
# 3                   0             0            0  ...   0.500000
# 4                   0             0            0  ...   0.500000
# ...               ...           ...          ...  ...        ...
# 7335                1             0            0  ...   0.866025
# 7336                1             0            0  ...   0.866025
# 7337                1             0            0  ...   0.866025
# 7338                1             0            0  ...   0.866025
# 7339                1             0            0  ...   0.866025
#
#       Days_until_next_SuperBowl  Days_since_last_SuperBowl  \
# 0                             7                      999.0
# 1                             7                      999.0
# 2                             7                      999.0
# 3                             7                      999.0
# 4                             7                      999.0
# ...                         ...                        ...
# 7335                         77                      287.0
# 7336                         77                      287.0
# 7337                         77                      287.0
# 7338                         77                      287.0
# 7339                         77                      287.0
#
#       Days_until_next_Thanksgiving  Days_since_last_Thanksgiving  \
# 0                              294                         999.0
# 1                              294                         999.0
# 2                              294                         999.0
# 3                              294                         999.0
# 4                              294                         999.0
# ...                            ...                           ...
# 7335                             0                         364.0
# 7336                             0                         364.0
# 7337                             0                         364.0
# 7338                             0                         364.0
# 7339                             0                         364.0
#
#       Days_until_next_Christmas  Days_since_last_Christmas  \
# 0                           329                      999.0
# 1                           329                      999.0
# 2                           329                      999.0
# 3                           329                      999.0
# 4                           329                      999.0
# ...                         ...                        ...
# 7335                         35                      329.0
# 7336                         35                      329.0
# 7337                         35                      329.0
# 7338                         35                      329.0
# 7339                         35                      329.0
#
#       Days_until_next_LaborDay  Days_since_last_LaborDay  Date
# 0                          217                     999.0     0
# 1                          217                     999.0     0
# 2                          217                     999.0     0
# 3                          217                     999.0     0
# 4                          217                     999.0     0
# ...                        ...                       ...   ...
# 7335                       287                      77.0    94
# 7336                       287                      77.0    94
# 7337                       287                      77.0    94
# 7338                       287                      77.0    94
# 7339                       287                      77.0    94
#
# [7340 rows x 33 columns]

# %%
from xgboost import XGBRegressor
from src.utils import wmae
from src.cross_validation import manual_model_search

model = XGBRegressor(
    objective='reg:squarederror',
    enable_categorical=True,
    random_state=42
)

param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.05, 0.1],
    'max_depth': [3, 5, 7],
}


metric_kwargs = {
    'is_holiday': X_valid_dept['IsHoliday']
}

best_model, best_params, best_score = manual_model_search(
    model=model,
    param_grid=param_grid,
    X_train=X_train_dept,
    y_train=y_train_dept,
    X_valid=X_valid_dept,
    y_valid=y_valid_dept,
    metric_func=wmae,
    metric_kwargs=metric_kwargs
)

print("\nBest Params:", best_params)
print("Best Validation Score:", best_score)
# Out:
# Params: {'n_estimators': 50, 'learning_rate': 0.01, 'max_depth': 3} -> Score: 8121.7384
# Params: {'n_estimators': 50, 'learning_rate': 0.01, 'max_depth': 5} -> Score: 8058.3132
# Params: {'n_estimators': 50, 'learning_rate': 0.01, 'max_depth': 7} -> Score: 7969.8613
# Params: {'n_estimators': 50, 'learning_rate': 0.05, 'max_depth': 3} -> Score: 2688.5536
# Params: {'n_estimators': 50, 'learning_rate': 0.05, 'max_depth': 5} -> Score: 2257.7474
# Params: {'n_estimators': 50, 'learning_rate': 0.05, 'max_depth': 7} -> Score: 2017.7425
# Params: {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 3} -> Score: 1873.3665
# Params: {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 5} -> Score: 1502.4315
# Params: {'n_estimators': 50, 'learning_rate': 0.1, 'max_depth': 7} -> Score: 1297.3211
# Params: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 3} -> Score: 5476.6441
# Params: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 5} -> Score: 5379.8402
# Params: {'n_estimators': 100, 'learning_rate': 0.01, 'max_depth': 7} -> Score: 5230.3680
# Params: {'n_estimators': 100, 'learning_rate': 0.05, 'max_depth': 3} -> Score: 1912.8670
# Params: {'n_estimators': 100, 'learning_rate': 0.05, 'max_depth': 5} -> Score: 1482.4340
# Params: {'n_estimators': 100, 'learning_rate': 0.05, 'max_depth': 7} -> Score: 1291.2216
# Params: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 3} -> Score: 1536.3171
# Params: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 5} -> Score: 1227.7514
# Params: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 7} -> Score: 1171.7610
# Params: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 3} -> Score: 3166.8087
# Params: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 5} -> Score: 2847.9870
# Params: {'n_estimators': 200, 'learning_rate': 0.01, 'max_depth': 7} -> Score: 2607.6679
# Params: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 3} -> Score: 1551.9595
# Params: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 5} -> Score: 1228.8589
# Params: {'n_estimators': 200, 'learning_rate': 0.05, 'max_depth': 7} -> Score: 1138.2821
# Params: {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 3} -> Score: 2527.8551
# Params: {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 5} -> Score: 1218.6011
# Params: {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 7} -> Score: 1122.1801
#
# Best Params: {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 7}
# Best Validation Score: 1122.1801172750068

# %%
from xgboost import XGBRegressor
from src.utils import wmae
from src.cross_validation import manual_model_search

model = XGBRegressor(
    objective='reg:squarederror',
    enable_categorical=True,
    random_state=42,
    n_estimators=200,
    learning_rate=0.1,
    max_depth=7,
)

param_grid = {
    'subsample': [0.6, 0.8, 1.0],
    'colsample_bytree': [0.5, 0.7, 1.0],
    'min_child_weight': [1, 5, 10],
    'n_estimators': [200, 300],
}

metric_kwargs = {
    'is_holiday': X_valid_dept['IsHoliday']
}

best_model, best_params, best_score = manual_model_search(
    model=model,
    param_grid=param_grid,
    X_train=X_train_dept,
    y_train=y_train_dept,
    X_valid=X_valid_dept,
    y_valid=y_valid_dept,
    metric_func=wmae,
    metric_kwargs=metric_kwargs
)

print("\nBest Params:", best_params)
print("Best Validation Score:", best_score)
# Out:
# Params: {'subsample': 0.6, 'colsample_bytree': 0.5, 'min_child_weight': 1, 'n_estimators': 200} -> Score: 1401.3283
# Params: {'subsample': 0.6, 'colsample_bytree': 0.5, 'min_child_weight': 1, 'n_estimators': 300} -> Score: 1386.3900
# Params: {'subsample': 0.6, 'colsample_bytree': 0.5, 'min_child_weight': 5, 'n_estimators': 200} -> Score: 1406.2531
# Params: {'subsample': 0.6, 'colsample_bytree': 0.5, 'min_child_weight': 5, 'n_estimators': 300} -> Score: 1372.4439
# Params: {'subsample': 0.6, 'colsample_bytree': 0.5, 'min_child_weight': 10, 'n_estimators': 200} -> Score: 1618.1366
# Params: {'subsample': 0.6, 'colsample_bytree': 0.5, 'min_child_weight': 10, 'n_estimators': 300} -> Score: 1553.6421
# Params: {'subsample': 0.6, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'n_estimators': 200} -> Score: 1497.9736
# Params: {'subsample': 0.6, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'n_estimators': 300} -> Score: 1488.0840
# Params: {'subsample': 0.6, 'colsample_bytree': 0.7, 'min_child_weight': 5, 'n_estimators': 200} -> Score: 1541.8468
# Params: {'subsample': 0.6, 'colsample_bytree': 0.7, 'min_child_weight': 5, 'n_estimators': 300} -> Score: 1495.7843
# Params: {'subsample': 0.6, 'colsample_bytree': 0.7, 'min_child_weight': 10, 'n_estimators': 200} -> Score: 1606.4524
# Params: {'subsample': 0.6, 'colsample_bytree': 0.7, 'min_child_weight': 10, 'n_estimators': 300} -> Score: 1618.0261
# Params: {'subsample': 0.6, 'colsample_bytree': 1.0, 'min_child_weight': 1, 'n_estimators': 200} -> Score: 1695.7045
# Params: {'subsample': 0.6, 'colsample_bytree': 1.0, 'min_child_weight': 1, 'n_estimators': 300} -> Score: 1693.0611
# Params: {'subsample': 0.6, 'colsample_bytree': 1.0, 'min_child_weight': 5, 'n_estimators': 200} -> Score: 1597.9529
# Params: {'subsample': 0.6, 'colsample_bytree': 1.0, 'min_child_weight': 5, 'n_estimators': 300} -> Score: 1559.4902
# Params: {'subsample': 0.6, 'colsample_bytree': 1.0, 'min_child_weight': 10, 'n_estimators': 200} -> Score: 1735.1484
# Params: {'subsample': 0.6, 'colsample_bytree': 1.0, 'min_child_weight': 10, 'n_estimators': 300} -> Score: 1683.6343
# Params: {'subsample': 0.8, 'colsample_bytree': 0.5, 'min_child_weight': 1, 'n_estimators': 200} -> Score: 1272.5909
# Params: {'subsample': 0.8, 'colsample_bytree': 0.5, 'min_child_weight': 1, 'n_estimators': 300} -> Score: 1280.2286
# Params: {'subsample': 0.8, 'colsample_bytree': 0.5, 'min_child_weight': 5, 'n_estimators': 200} -> Score: 1451.0172
# Params: {'subsample': 0.8, 'colsample_bytree': 0.5, 'min_child_weight': 5, 'n_estimators': 300} -> Score: 1372.3139
# Params: {'subsample': 0.8, 'colsample_bytree': 0.5, 'min_child_weight': 10, 'n_estimators': 200} -> Score: 1464.3168
# Params: {'subsample': 0.8, 'colsample_bytree': 0.5, 'min_child_weight': 10, 'n_estimators': 300} -> Score: 1377.1632
# Params: {'subsample': 0.8, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'n_estimators': 200} -> Score: 1231.1762
# Params: {'subsample': 0.8, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'n_estimators': 300} -> Score: 1219.2138
# Params: {'subsample': 0.8, 'colsample_bytree': 0.7, 'min_child_weight': 5, 'n_estimators': 200} -> Score: 1407.3749
# Params: {'subsample': 0.8, 'colsample_bytree': 0.7, 'min_child_weight': 5, 'n_estimators': 300} -> Score: 1380.2366
# Params: {'subsample': 0.8, 'colsample_bytree': 0.7, 'min_child_weight': 10, 'n_estimators': 200} -> Score: 1325.8788
# Params: {'subsample': 0.8, 'colsample_bytree': 0.7, 'min_child_weight': 10, 'n_estimators': 300} -> Score: 1358.2442
# Params: {'subsample': 0.8, 'colsample_bytree': 1.0, 'min_child_weight': 1, 'n_estimators': 200} -> Score: 1434.4745
# Params: {'subsample': 0.8, 'colsample_bytree': 1.0, 'min_child_weight': 1, 'n_estimators': 300} -> Score: 1437.8406
# Params: {'subsample': 0.8, 'colsample_bytree': 1.0, 'min_child_weight': 5, 'n_estimators': 200} -> Score: 1384.9858
# Params: {'subsample': 0.8, 'colsample_bytree': 1.0, 'min_child_weight': 5, 'n_estimators': 300} -> Score: 1358.4565
# Params: {'subsample': 0.8, 'colsample_bytree': 1.0, 'min_child_weight': 10, 'n_estimators': 200} -> Score: 1353.8817
# Params: {'subsample': 0.8, 'colsample_bytree': 1.0, 'min_child_weight': 10, 'n_estimators': 300} -> Score: 1278.3032
# Params: {'subsample': 1.0, 'colsample_bytree': 0.5, 'min_child_weight': 1, 'n_estimators': 200} -> Score: 1039.7686
# Params: {'subsample': 1.0, 'colsample_bytree': 0.5, 'min_child_weight': 1, 'n_estimators': 300} -> Score: 1033.4039
# Params: {'subsample': 1.0, 'colsample_bytree': 0.5, 'min_child_weight': 5, 'n_estimators': 200} -> Score: 1263.2877
# Params: {'subsample': 1.0, 'colsample_bytree': 0.5, 'min_child_weight': 5, 'n_estimators': 300} -> Score: 1200.5198
# Params: {'subsample': 1.0, 'colsample_bytree': 0.5, 'min_child_weight': 10, 'n_estimators': 200} -> Score: 1368.9818
# Params: {'subsample': 1.0, 'colsample_bytree': 0.5, 'min_child_weight': 10, 'n_estimators': 300} -> Score: 1317.8310
# Params: {'subsample': 1.0, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'n_estimators': 200} -> Score: 1082.8858
# Params: {'subsample': 1.0, 'colsample_bytree': 0.7, 'min_child_weight': 1, 'n_estimators': 300} -> Score: 1085.0722
# Params: {'subsample': 1.0, 'colsample_bytree': 0.7, 'min_child_weight': 5, 'n_estimators': 200} -> Score: 1154.4776
# Params: {'subsample': 1.0, 'colsample_bytree': 0.7, 'min_child_weight': 5, 'n_estimators': 300} -> Score: 1126.6618
# Params: {'subsample': 1.0, 'colsample_bytree': 0.7, 'min_child_weight': 10, 'n_estimators': 200} -> Score: 1259.7687
# Params: {'subsample': 1.0, 'colsample_bytree': 0.7, 'min_child_weight': 10, 'n_estimators': 300} -> Score: 1197.4439
# Params: {'subsample': 1.0, 'colsample_bytree': 1.0, 'min_child_weight': 1, 'n_estimators': 200} -> Score: 1122.1801
# Params: {'subsample': 1.0, 'colsample_bytree': 1.0, 'min_child_weight': 1, 'n_estimators': 300} -> Score: 1132.1316
# Params: {'subsample': 1.0, 'colsample_bytree': 1.0, 'min_child_weight': 5, 'n_estimators': 200} -> Score: 1180.6635
# Params: {'subsample': 1.0, 'colsample_bytree': 1.0, 'min_child_weight': 5, 'n_estimators': 300} -> Score: 1160.8661
# Params: {'subsample': 1.0, 'colsample_bytree': 1.0, 'min_child_weight': 10, 'n_estimators': 200} -> Score: 1136.9444
# Params: {'subsample': 1.0, 'colsample_bytree': 1.0, 'min_child_weight': 10, 'n_estimators': 300} -> Score: 1078.9695
#
# Best Params: {'subsample': 1.0, 'colsample_bytree': 0.5, 'min_child_weight': 1, 'n_estimators': 300}
# Best Validation Score: 1033.4038754172311

# %%
from re import sub
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error
from src.utils import wmae as compute_wmae

dept_model = XGBRegressor(
    objective='reg:squarederror',
    enable_categorical=True,
    random_state=42,
    n_estimators=300,
    learning_rate=0.1,
    max_depth=7,
    subsample=1.0,
    colsample_bytree=0.5,
    min_child_weight=1
)

dept_model.fit(X_train_dept, y_train_dept)
dept_train_preds = dept_model.predict(X_train_dept)
dept_valid_preds = dept_model.predict(X_valid_dept)

wma = compute_wmae(y_valid_dept, dept_valid_preds, is_holiday=X_valid_dept['IsHoliday'])
print(f"Validation WMAE: {wma:.2f}")
mae = mean_absolute_error(y_valid_dept, dept_valid_preds)
print(f"Validation MAE: {mae:.2f}")

wma = compute_wmae(y_train_dept, dept_train_preds, is_holiday=X_train_dept['IsHoliday'])
print(f"Train WMAE: {wma:.2f}")
mae = mean_absolute_error(y_train_dept, dept_train_preds)
print(f"Train MAE: {mae:.2f}")
# Out:
# Validation WMAE: 1033.40
# Validation MAE: 1001.65
# Train WMAE: 251.57
# Train MAE: 264.37

# %%
valid_dept_results = X_valid_dept[['Dept', 'Date']].copy()
valid_dept_results['Dept_Prediction'] = dept_valid_preds

train_dept_results = X_train_dept[['Dept', 'Date']].copy()
train_dept_results['Dept_Prediction'] = dept_train_preds

valid_dept_results
# Out:
#      Dept  Date  Dept_Prediction
# 0       1    95     21880.861328
# 1       2    95     41118.820312
# 2       3    95      9410.833008
# 3       4    95     26376.099609
# 4       5    95     36223.613281
# ...   ...   ...              ...
# 3745   95   142     65395.964844
# 3746   96   142     15374.616211
# 3747   97   142     13295.514648
# 3748   98   142      6885.061035
# 3749   99   142       361.246094
#
# [3750 rows x 3 columns]

# %% [markdown]
# # Overall Model

# %%
params = {
    'add_week_num' : True,
    'add_holiday_flags' : True,
    'add_holiday_proximity': True,
    'add_holiday_windows': True,
    'add_fourier_features': True,
    'add_month_and_year': True,
    'replace_time_index': True,
}

feature_adder = time_features.FeatureAdder(**params)
X_train_t = feature_adder.fit_transform(X_train)
X_valid_t = feature_adder.transform(X_valid)

object_transformer = feature_transformers.ObjectToCategory()
X_train_t = object_transformer.fit_transform(X_train_t)
X_valid_t = object_transformer.transform(X_valid_t)

make_categorical_transformer = feature_transformers.MakeCategorical(['Dept', 'Store'])
X_train_t = make_categorical_transformer.fit_transform(X_train_t)
X_valid_t = make_categorical_transformer.transform(X_valid_t)


X_train_t
# Out:
#        Store Dept  IsHoliday  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0          1    1      False        42.31       2.572        NaN        NaN
# 1          1    2      False        42.31       2.572        NaN        NaN
# 2          1    3      False        42.31       2.572        NaN        NaN
# 3          1    4      False        42.31       2.572        NaN        NaN
# 4          1    5      False        42.31       2.572        NaN        NaN
# ...      ...  ...        ...          ...         ...        ...        ...
# 279080    45   93       True        48.71       3.492     140.87     384.82
# 279081    45   94       True        48.71       3.492     140.87     384.82
# 279082    45   95       True        48.71       3.492     140.87     384.82
# 279083    45   97       True        48.71       3.492     140.87     384.82
# 279084    45   98       True        48.71       3.492     140.87     384.82
#
#         MarkDown3  MarkDown4  MarkDown5  ...  month_cos  \
# 0             NaN        NaN        NaN  ...   0.500000
# 1             NaN        NaN        NaN  ...   0.500000
# 2             NaN        NaN        NaN  ...   0.500000
# 3             NaN        NaN        NaN  ...   0.500000
# 4             NaN        NaN        NaN  ...   0.500000
# ...           ...        ...        ...  ...        ...
# 279080   26961.99      28.59    1110.12  ...   0.866025
# 279081   26961.99      28.59    1110.12  ...   0.866025
# 279082   26961.99      28.59    1110.12  ...   0.866025
# 279083   26961.99      28.59    1110.12  ...   0.866025
# 279084   26961.99      28.59    1110.12  ...   0.866025
#
#         Days_until_next_SuperBowl Days_since_last_SuperBowl  \
# 0                               7                     999.0
# 1                               7                     999.0
# 2                               7                     999.0
# 3                               7                     999.0
# 4                               7                     999.0
# ...                           ...                       ...
# 279080                         77                     287.0
# 279081                         77                     287.0
# 279082                         77                     287.0
# 279083                         77                     287.0
# 279084                         77                     287.0
#
#         Days_until_next_Thanksgiving  Days_since_last_Thanksgiving  \
# 0                                294                         999.0
# 1                                294                         999.0
# 2                                294                         999.0
# 3                                294                         999.0
# 4                                294                         999.0
# ...                              ...                           ...
# 279080                             0                         364.0
# 279081                             0                         364.0
# 279082                             0                         364.0
# 279083                             0                         364.0
# 279084                             0                         364.0
#
#         Days_until_next_Christmas  Days_since_last_Christmas  \
# 0                             329                      999.0
# 1                             329                      999.0
# 2                             329                      999.0
# 3                             329                      999.0
# 4                             329                      999.0
# ...                           ...                        ...
# 279080                         35                      329.0
# 279081                         35                      329.0
# 279082                         35                      329.0
# 279083                         35                      329.0
# 279084                         35                      329.0
#
#         Days_until_next_LaborDay  Days_since_last_LaborDay  Date
# 0                            217                     999.0     0
# 1                            217                     999.0     0
# 2                            217                     999.0     0
# 3                            217                     999.0     0
# 4                            217                     999.0     0
# ...                          ...                       ...   ...
# 279080                       287                      77.0    94
# 279081                       287                      77.0    94
# 279082                       287                      77.0    94
# 279083                       287                      77.0    94
# 279084                       287                      77.0    94
#
# [279085 rows x 44 columns]

# %%
X_train_T = X_train_t.merge(train_dept_results, on=['Date', 'Dept'], how='left')
X_train_T = X_train_T.merge(train_store_results, on=['Date', 'Store'], how='left')
X_train_T
# Out:
#        Store Dept  IsHoliday  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0          1    1      False        42.31       2.572        NaN        NaN
# 1          1    2      False        42.31       2.572        NaN        NaN
# 2          1    3      False        42.31       2.572        NaN        NaN
# 3          1    4      False        42.31       2.572        NaN        NaN
# 4          1    5      False        42.31       2.572        NaN        NaN
# ...      ...  ...        ...          ...         ...        ...        ...
# 279080    45   93       True        48.71       3.492     140.87     384.82
# 279081    45   94       True        48.71       3.492     140.87     384.82
# 279082    45   95       True        48.71       3.492     140.87     384.82
# 279083    45   97       True        48.71       3.492     140.87     384.82
# 279084    45   98       True        48.71       3.492     140.87     384.82
#
#         MarkDown3  MarkDown4  MarkDown5  ...  Days_since_last_SuperBowl  \
# 0             NaN        NaN        NaN  ...                      999.0
# 1             NaN        NaN        NaN  ...                      999.0
# 2             NaN        NaN        NaN  ...                      999.0
# 3             NaN        NaN        NaN  ...                      999.0
# 4             NaN        NaN        NaN  ...                      999.0
# ...           ...        ...        ...  ...                        ...
# 279080   26961.99      28.59    1110.12  ...                      287.0
# 279081   26961.99      28.59    1110.12  ...                      287.0
# 279082   26961.99      28.59    1110.12  ...                      287.0
# 279083   26961.99      28.59    1110.12  ...                      287.0
# 279084   26961.99      28.59    1110.12  ...                      287.0
#
#         Days_until_next_Thanksgiving Days_since_last_Thanksgiving  \
# 0                                294                        999.0
# 1                                294                        999.0
# 2                                294                        999.0
# 3                                294                        999.0
# 4                                294                        999.0
# ...                              ...                          ...
# 279080                             0                        364.0
# 279081                             0                        364.0
# 279082                             0                        364.0
# 279083                             0                        364.0
# 279084                             0                        364.0
#
#         Days_until_next_Christmas  Days_since_last_Christmas  \
# 0                             329                      999.0
# 1                             329                      999.0
# 2                             329                      999.0
# 3                             329                      999.0
# 4                             329                      999.0
# ...                           ...                        ...
# 279080                         35                      329.0
# 279081                         35                      329.0
# 279082                         35                      329.0
# 279083                         35                      329.0
# 279084                         35                      329.0
#
#         Days_until_next_LaborDay  Days_since_last_LaborDay  Date  \
# 0                            217                     999.0     0
# 1                            217                     999.0     0
# 2                            217                     999.0     0
# 3                            217                     999.0     0
# 4                            217                     999.0     0
# ...                          ...                       ...   ...
# 279080                       287                      77.0    94
# 279081                       287                      77.0    94
# 279082                       287                      77.0    94
# 279083                       287                      77.0    94
# 279084                       287                      77.0    94
#
#         Dept_Prediction  Store_Prediction
# 0          19939.005859      22419.216797
# 1          44170.718750      22419.216797
# 2          10905.104492      22419.216797
# 3          26510.585938      22419.216797
# 4          25128.974609      22419.216797
# ...                 ...               ...
# 279080     32346.962891      17340.208984
# 279081     32151.175781      17340.208984
# 279082     64336.171875      17340.208984
# 279083     12398.745117      17340.208984
# 279084      9847.995117      17340.208984
#
# [279085 rows x 46 columns]

# %%
X_valid_T = X_valid_t.merge(valid_dept_results, on=['Date', 'Dept'], how='left')
X_valid_T = X_valid_T.merge(valid_store_results, on=['Date', 'Store'], how='left')
X_valid_T
# Out:
#        Store Dept  IsHoliday  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0          1    1      False        48.91       3.172    5629.51      68.00
# 1          1    2      False        48.91       3.172    5629.51      68.00
# 2          1    3      False        48.91       3.172    5629.51      68.00
# 3          1    4      False        48.91       3.172    5629.51      68.00
# 4          1    5      False        48.91       3.172    5629.51      68.00
# ...      ...  ...        ...          ...         ...        ...        ...
# 142480    45   93      False        58.85       3.882    4018.91      58.08
# 142481    45   94      False        58.85       3.882    4018.91      58.08
# 142482    45   95      False        58.85       3.882    4018.91      58.08
# 142483    45   97      False        58.85       3.882    4018.91      58.08
# 142484    45   98      False        58.85       3.882    4018.91      58.08
#
#         MarkDown3  MarkDown4  MarkDown5  ...  Days_since_last_SuperBowl  \
# 0         1398.11    2084.64   20475.32  ...                        294
# 1         1398.11    2084.64   20475.32  ...                        294
# 2         1398.11    2084.64   20475.32  ...                        294
# 3         1398.11    2084.64   20475.32  ...                        294
# 4         1398.11    2084.64   20475.32  ...                        294
# ...           ...        ...        ...  ...                        ...
# 142480     100.00     211.94     858.33  ...                        259
# 142481     100.00     211.94     858.33  ...                        259
# 142482     100.00     211.94     858.33  ...                        259
# 142483     100.00     211.94     858.33  ...                        259
# 142484     100.00     211.94     858.33  ...                        259
#
#         Days_until_next_Thanksgiving Days_since_last_Thanksgiving  \
# 0                                357                            7
# 1                                357                            7
# 2                                357                            7
# 3                                357                            7
# 4                                357                            7
# ...                              ...                          ...
# 142480                            28                          336
# 142481                            28                          336
# 142482                            28                          336
# 142483                            28                          336
# 142484                            28                          336
#
#         Days_until_next_Christmas  Days_since_last_Christmas  \
# 0                              28                        336
# 1                              28                        336
# 2                              28                        336
# 3                              28                        336
# 4                              28                        336
# ...                           ...                        ...
# 142480                         63                        301
# 142481                         63                        301
# 142482                         63                        301
# 142483                         63                        301
# 142484                         63                        301
#
#         Days_until_next_LaborDay  Days_since_last_LaborDay  Date  \
# 0                            280                        84    95
# 1                            280                        84    95
# 2                            280                        84    95
# 3                            280                        84    95
# 4                            280                        84    95
# ...                          ...                       ...   ...
# 142480                       315                        49   142
# 142481                       315                        49   142
# 142482                       315                        49   142
# 142483                       315                        49   142
# 142484                       315                        49   142
#
#         Dept_Prediction  Store_Prediction
# 0          21880.861328      23446.662109
# 1          41118.820312      23446.662109
# 2           9410.833008      23446.662109
# 3          26376.099609      23446.662109
# 4          36223.613281      23446.662109
# ...                 ...               ...
# 142480     24706.046875      11497.519531
# 142481     28365.982422      11497.519531
# 142482     65395.964844      11497.519531
# 142483     13295.514648      11497.519531
# 142484      6885.061035      11497.519531
#
# [142485 rows x 46 columns]

# %%
import lightgbm as lgb

model = lgb.LGBMRegressor(
    objective='regression',
    random_state=42,
    verbose=-1
)

param_grid = {
    'n_estimators': [500, 700, 1000],
    'learning_rate': [0.05, 0.1, 0.2],
    'max_depth': [7, 10, 15],
}


metric_kwargs = {
    'is_holiday': X_valid_T['IsHoliday']
}

best_model, best_params, best_score = manual_model_search(
    model=model,
    param_grid=param_grid,
    X_train=X_train_T,
    y_train=y_train,
    X_valid=X_valid_T,
    y_valid=y_valid,
    metric_func=wmae,
    metric_kwargs=metric_kwargs
)

print("\nBest Params:", best_params)
print("Best Validation Score:", best_score)
# Out:
# Params: {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 7} -> Score: 2229.2899
# Params: {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 10} -> Score: 2236.3063
# Params: {'n_estimators': 500, 'learning_rate': 0.05, 'max_depth': 15} -> Score: 2239.9927
# Params: {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 7} -> Score: 2010.4447
# Params: {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 10} -> Score: 2005.1945
# Params: {'n_estimators': 500, 'learning_rate': 0.1, 'max_depth': 15} -> Score: 2013.2947
# Params: {'n_estimators': 500, 'learning_rate': 0.2, 'max_depth': 7} -> Score: 1988.8651
# Params: {'n_estimators': 500, 'learning_rate': 0.2, 'max_depth': 10} -> Score: 1984.3639
# Params: {'n_estimators': 500, 'learning_rate': 0.2, 'max_depth': 15} -> Score: 1982.7143
# Params: {'n_estimators': 700, 'learning_rate': 0.05, 'max_depth': 7} -> Score: 2098.9364
# Params: {'n_estimators': 700, 'learning_rate': 0.05, 'max_depth': 10} -> Score: 2110.5981
# Params: {'n_estimators': 700, 'learning_rate': 0.05, 'max_depth': 15} -> Score: 2113.9016
# Params: {'n_estimators': 700, 'learning_rate': 0.1, 'max_depth': 7} -> Score: 1958.1166
# Params: {'n_estimators': 700, 'learning_rate': 0.1, 'max_depth': 10} -> Score: 1944.0096
# Params: {'n_estimators': 700, 'learning_rate': 0.1, 'max_depth': 15} -> Score: 1962.9809
# Params: {'n_estimators': 700, 'learning_rate': 0.2, 'max_depth': 7} -> Score: 1959.6882
# Params: {'n_estimators': 700, 'learning_rate': 0.2, 'max_depth': 10} -> Score: 1957.8963
# Params: {'n_estimators': 700, 'learning_rate': 0.2, 'max_depth': 15} -> Score: 1968.6790
# Params: {'n_estimators': 1000, 'learning_rate': 0.05, 'max_depth': 7} -> Score: 2004.0812
# Params: {'n_estimators': 1000, 'learning_rate': 0.05, 'max_depth': 10} -> Score: 2012.1221
# Params: {'n_estimators': 1000, 'learning_rate': 0.05, 'max_depth': 15} -> Score: 2014.4646
# Params: {'n_estimators': 1000, 'learning_rate': 0.1, 'max_depth': 7} -> Score: 1924.4140
# Params: {'n_estimators': 1000, 'learning_rate': 0.1, 'max_depth': 10} -> Score: 1909.8925
# Params: {'n_estimators': 1000, 'learning_rate': 0.1, 'max_depth': 15} -> Score: 1934.8703
# Params: {'n_estimators': 1000, 'learning_rate': 0.2, 'max_depth': 7} -> Score: 1944.1085
# Params: {'n_estimators': 1000, 'learning_rate': 0.2, 'max_depth': 10} -> Score: 1947.1166
# Params: {'n_estimators': 1000, 'learning_rate': 0.2, 'max_depth': 15} -> Score: 1961.8820
#
# Best Params: {'n_estimators': 1000, 'learning_rate': 0.1, 'max_depth': 10}
# Best Validation Score: 1909.8925352221652

# %%
import lightgbm as lgb
import pandas as pd
from sklearn.metrics import mean_absolute_error
from src.utils import wmae as compute_wmae

model = lgb.LGBMRegressor(
    objective='regression',
    random_state=42,
    verbose=-1,
    n_estimators=1000,
    learning_rate=0.1,
    max_depth=10
)

model.fit(X_train_T, y_train)

train_preds = model.predict(X_train_T)
valid_preds = model.predict(X_valid_T)

train_wmae = compute_wmae(y_train, train_preds, is_holiday=X_train_T['IsHoliday'])
valid_wmae = compute_wmae(y_valid, valid_preds, is_holiday=X_valid_T['IsHoliday'])
train_mae = mean_absolute_error(y_train, train_preds)
valid_mae = mean_absolute_error(y_valid, valid_preds)

print(f"Train WMAE: {train_wmae:.2f}, MAE: {train_mae:.2f}")
print(f"Valid WMAE: {valid_wmae:.2f}, MAE: {valid_mae:.2f}")
# Out:
# Train WMAE: 1155.79, MAE: 1123.76
# Valid WMAE: 1909.89, MAE: 1881.72

# %%
from models import group_stat
import importlib
importlib.reload(group_stat)

mdl = group_stat.GroupStatModel()

mdl.fit(X_train, y_train)

pred = mdl.predict(X_valid)

valid_wmae = compute_wmae(y_valid, pred, is_holiday=X_valid_T['IsHoliday'])
print(f"Valid WMAE: {valid_wmae:.2f}")
# Out:
# Valid WMAE: 1917.63
